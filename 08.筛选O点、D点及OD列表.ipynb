# %%
from sqlalchemy import create_engine
import pyodbc
import pandas as pd
import numpy as np
import time

# %% [markdown]
# # 1读取数据库数据表

# %%
engine = create_engine('mssql+pyodbc://sa:suzhou@.\SQLEXPRESS/FCDBackup20100900_new?driver=SQL server')

# %%
with engine.connect() as conn,conn.begin():
    data = pd.read_sql_table('VehicleData20100901',conn)

# %%
data.head()
# Out:
#      ID CompanyID  VehicleSimID             GPSTime  GPSLongitude  \
# 0  6304      None  806584008859 2010-09-01 00:01:42    118.855043
# 1  6381      None  806770549907 2010-09-01 00:01:45    118.749090
# 2  6460      None  806770943693 2010-09-01 00:01:46    118.856236
# 3  6537      None  806914743134 2010-09-01 00:01:48    118.836872
# 4  6615      None  806451847007 2010-09-01 00:01:51    118.795597
#
#    GPSLatitude  GPSSpeed  GPSDirection  PassengerState  ReadFlag  \
# 0    31.939446       0.0           0.0               0         0
# 1    32.089162      30.0           6.0               1         0
# 2    32.094288      26.0         318.0               1         0
# 3    31.931645       0.0           0.0               0         0
# 4    32.039382      20.0          10.0               0         0
#
#                CreateDate
# 0 2010-09-01 00:01:42.730
# 1 2010-09-01 00:01:45.140
# 2 2010-09-01 00:01:46.747
# 3 2010-09-01 00:01:48.733
# 4 2010-09-01 00:01:51.590

# %%
len(data)
# Out:
# 18668073

# %% [markdown]
# # 2样本筛选分析

# %%
dm = data[data['VehicleSimID'] == '806584008859']

# %%
dm = dm[['VehicleSimID','GPSTime','GPSLongitude','GPSLatitude','PassengerState']]

# %%
dm.to_excel(r'D:\Vgis_data\Multi-Source-Data\show\SIM_806584008859.xlsx',sheet_name='a')

# %%
dm.head()
# Out:
#        VehicleSimID             GPSTime  GPSLongitude  GPSLatitude  \
# 0      806584008859 2010-09-01 00:01:42    118.855043    31.939446
# 17774  806584008859 2010-09-01 00:04:14    118.855038    31.939426
# 27998  806584008859 2010-09-01 00:04:57    118.855024    31.939432
# 36769  806584008859 2010-09-01 00:05:35    118.855055    31.939318
# 47558  806584008859 2010-09-01 00:06:20    118.855182    31.938821
#
#        PassengerState
# 0                   0
# 17774               0
# 27998               0
# 36769               0
# 47558               0

# %% [markdown]
# ## 获取O点

# %%
def get_orig():
    appended_data = []
    if dm['PassengerState'][0] == 1:
        df_first = dm.iloc[0:1,:]
        Orig = dm['PassengerState'].diff() == 1
        appended_data.append(df_first)
        appended_data.append(dm[Orig])
    else:
        Orig = dm['PassengerState'].diff() == 1
        appended_data.append(dm[Orig])
    return appended_data

# %%
data_o = get_orig()
All_Orig = pd.concat(data_o,axis=0)
All_Orig
# Out:
#           VehicleSimID             GPSTime  GPSLongitude  GPSLatitude  \
# 374463    806584008859 2010-09-01 00:29:32    118.872466    31.941964
# 7262193   806584008859 2010-09-01 08:40:49    118.872645    31.942027
# 7735372   806584008859 2010-09-01 09:14:20    118.849378    31.952004
# 8215564   806584008859 2010-09-01 09:48:16    118.823456    31.914543
# 8307591   806584008859 2010-09-01 09:54:46    118.822055    31.896905
# 8758750   806584008859 2010-09-01 10:26:36    118.824048    31.913635
# 11410397  806584008859 2010-09-01 13:37:06    118.783159    31.944999
# 17164679  806584008859 2010-09-01 21:04:56    118.816164    31.936671
# 17370395  806584008859 2010-09-01 21:20:35    118.816287    31.930966
# 17746107  806584008859 2010-09-01 21:49:13    118.831471    31.910919
# 18043755  806584008859 2010-09-01 22:12:05    118.851803    31.914733
# 18278485  806584008859 2010-09-01 22:30:10    118.828448    31.953932
# 18453419  806584008859 2010-09-01 20:03:49    118.921103    32.048881
# 18461809  806584008859 2010-09-01 18:59:16    118.864808    31.961666
# 18487077  806584008859 2010-09-01 16:38:11    118.889116    31.932155
# 18515078  806584008859 2010-09-01 14:06:02    118.814591    31.930327
# 18571430  806584008859 2010-09-01 08:56:02    118.869681    31.948251
#
#           PassengerState
# 573065                 1
# 7622213                1
# 8042172                1
# 8283322                1
# 8691730                1
# 9586743                1
# 11448201               1
# 11878067               1
# 12805381               1
# 13181342               1
# 13273196               1
# 14018317               1
# 14244476               1
# 14605316               1
# 16091880               1
# 16651843               1
# 17164679               1
# 17370395               1
# 17746107               1
# 18043755               1
# 18278485               1
# 18453419               1
# 18461809               1
# 18487077               1
# 18515078               1
# 18571430               1

# %% [markdown]
# ## 去获取OD经纬度坐标

# %%
dk = pd.DataFrame(np.random.randn(int(len(All_Orig)),4),
                  columns=['GPSLongitude_O','GPSLatitude_O','GPSLongitude_D','GPSLatitude_D'])

All_Orig.reset_index(inplace=True)
All_Dest.reset_index(inplace=True)

for i in range(0,len(All_Orig)):
    dk['GPSLongitude_O'][i] = All_Orig['GPSLongitude'][i]
    dk['GPSLatitude_O'][i] = All_Orig['GPSLatitude'][i]
    dk['GPSLongitude_D'][i] = All_Dest['GPSLongitude'][i]
    dk['GPSLatitude_D'][i] = All_Dest['GPSLatitude'][i]

# %%
All_Orig.reset_index(inplace=True)
All_Dest.reset_index(inplace=True)

for i in range(0,len(All_Orig)):
    dk['GPSLongitude_O'][i] = All_Orig['GPSLongitude'][i]
    dk['GPSLatitude_O'][i] = All_Orig['GPSLatitude'][i]
    dk['GPSLongitude_D'][i] = All_Dest['GPSLongitude'][i]
    dk['GPSLatitude_D'][i] = All_Dest['GPSLatitude'][i]

# %%
for i in range(0,len(All_Orig)):
    dk['GPSLongitude_O'][i] = All_Orig['GPSLongitude'][i]
    dk['GPSLatitude_O'][i] = All_Orig['GPSLatitude'][i]
    dk['GPSLongitude_D'][i] = All_Dest['GPSLongitude'][i]
    dk['GPSLatitude_D'][i] = All_Dest['GPSLatitude'][i]

# %%
dk
# Out:
#     GPSLongitude_O  GPSLatitude_O  GPSLongitude_D  GPSLatitude_D
# 0       118.872466      31.941964      118.818469      31.945203
# 1       118.872645      31.942027      118.846691      31.949271
# 2       118.849378      31.952004      118.824595      31.911223
# 3       118.823456      31.914543      118.822043      31.896929
# 4       118.822055      31.896905      118.821884      31.914805
# 5       118.824048      31.913635      118.725646      31.656411
# 6       118.783159      31.944999      118.782375      31.936879
# 7       118.816266      31.933043      118.803395      31.923832
# 8       118.859807      31.939852      118.880787      31.964085
# 9       118.880155      31.961259      118.874386      31.982365
# 10      118.874450      31.982446      118.852865      31.965338
# 11      118.872324      31.941960      118.914656      31.933717
# 12      118.908122      31.932554      118.871840      31.942231
# 13      118.877091      31.932761      118.877206      31.942781
# 14      118.872496      31.941823      118.864906      31.945631
# 15      118.921393      32.051963      118.922059      32.039932
# 16      118.847813      31.948955      118.816164      31.936671
# 17      118.816250      31.933300      118.816287      31.930966
# 18      118.831489      31.910687      118.831471      31.910919
# 19      118.844502      31.925630      118.851803      31.914733
# 20      118.827674      31.954150      118.828448      31.953932
# 21      118.921103      32.048881      118.921103      32.048881
# 22      118.855591      31.955378      118.864808      31.961666
# 23      118.889116      31.932155      118.889116      31.932155
# 24      118.862465      31.929187      118.814591      31.930327
# 25      118.869681      31.948251      118.869681      31.948251

# %% [markdown]
# # 3全数据应用

# %% [markdown]
# ## 按照SIMID进行聚合，便于后续筛选OD点

# %%
data.head()
# Out:
#      ID CompanyID  VehicleSimID             GPSTime  GPSLongitude  \
# 0  6304      None  806584008859 2010-09-01 00:01:42    118.855043
# 1  6381      None  806770549907 2010-09-01 00:01:45    118.749090
# 2  6460      None  806770943693 2010-09-01 00:01:46    118.856236
# 3  6537      None  806914743134 2010-09-01 00:01:48    118.836872
# 4  6615      None  806451847007 2010-09-01 00:01:51    118.795597
#
#    GPSLatitude  GPSSpeed  GPSDirection  PassengerState  ReadFlag  \
# 0    31.939446       0.0           0.0               0         0
# 1    32.089162      30.0           6.0               1         0
# 2    32.094288      26.0         318.0               1         0
# 3    31.931645       0.0           0.0               0         0
# 4    32.039382      20.0          10.0               0         0
#
#                CreateDate
# 0 2010-09-01 00:01:42.730
# 1 2010-09-01 00:01:45.140
# 2 2010-09-01 00:01:46.747
# 3 2010-09-01 00:01:48.733
# 4 2010-09-01 00:01:51.590

# %%
data = data[['VehicleSimID','GPSTime','GPSLongitude','GPSLatitude','PassengerState']]

# %%
data.head()
# Out:
#    VehicleSimID             GPSTime  GPSLongitude  GPSLatitude  PassengerState
# 0  806584008859 2010-09-01 00:01:42    118.855043    31.939446               0
# 1  806770549907 2010-09-01 00:01:45    118.749090    32.089162               1
# 2  806770943693 2010-09-01 00:01:46    118.856236    32.094288               1
# 3  806914743134 2010-09-01 00:01:48    118.836872    31.931645               0
# 4  806451847007 2010-09-01 00:01:51    118.795597    32.039382               0

# %%
gp = data.sort_values(by=['VehicleSimID','GPSTime']).groupby(by='VehicleSimID')

# %%
len(gp)
# Out:
# 7648

# %% [markdown]
# ## 获取所有的O点

# %%
def get_orig():
    appended_data = []
    for dm in gp:
        dm = list(dm)[1]
        dm.reset_index(inplace=True)
        if dm['PassengerState'][0] == 1:
            df_first = dm.iloc[0:1,:]
            Orig = dm['PassengerState'].diff() == 1
            appended_data.append(df_first)
            appended_data.append(dm[Orig])
        else:
            Orig = dm['PassengerState'].diff() == 1
            appended_data.append(dm[Orig])
    return appended_data

# %%
data_o = get_orig()
All_Orig = pd.concat(data_o,axis=0)
All_Orig
# Out:
#          index  VehicleSimID             GPSTime  GPSLongitude  GPSLatitude  \
# 0          985  806401925019 2010-09-01 00:00:11    118.897901    32.099258
# 72      721762  806401925019 2010-09-01 00:54:16    118.796564    32.084281
# 16919137  808950598417 2010-09-01 20:45:03    118.756869    32.028589
# 17377284  808950598417 2010-09-01 21:21:08    118.749428    32.075745
# 17686824  808950598417 2010-09-01 21:44:44    118.731949    32.075875
# 17856275  808950598417 2010-09-01 21:57:36    118.735857    32.056020
# 18157319  808950598417 2010-09-01 22:20:49    118.756362    32.083968
#
#           PassengerState
# 73543                  1
# 877649                 1
# 1398276                1
# 1605911                1
# 3457948                1
# 3516887                1
# 18566745               1
# 8369216                1
# 8699105                1
# 9043084                1
# 9550993                1
# 9779623                1
# 9948430                1
# 10412283               1
# 10833153               1
# 11621328               1
# 11972628               1
# 12322096               1
# 12514046               1
# 12864225               1
# 13273567               1
# 13835569               1
# 14112588               1
# 14397513               1
# 14614847               1
# 14843725               1
# 47937                  1
# 670116                 1
# 959356                 1
# 1174470                1
# ...                  ...
# 17613528               1
# 17790195               1
# 18118216               1
# 7322161                1
# 8015563                1
# 8615036                1
# 9117559                1
# 9388931                1
# 9760751                1
# 10165972               1
# 10485789               1
# 10837525               1
# 11455794               1
# 11555968               1
# 11732334               1
# 12121647               1
# 12695872               1
# 13204611               1
# 14443433               1
# 14889064               1
# 15160138               1
# 15383595               1
# 15808737               1
# 16082385               1
# 16146508               1
# 16919137               1
# 17377284               1
# 17686824               1
# 17856275               1
# 18157319               1
#
# [211866 rows x 5 columns]

# %%
All_Dest.to_csv(r'D:\Vgis_data\Multi-Source-Data\show\All_Dest.csv')

# %% [markdown]
# ## 获取所有的OD点坐标

# %%
def get_data(dt):    
    appended_data_orig = []
    dm = list(dt)[1]
    dm.reset_index(inplace=True)
    if dm['PassengerState'][0] == 1:
        df_first = dm.iloc[0:1,:]
        Orig = dm['PassengerState'].diff() == 1
        appended_data_orig.append(df_first)
        appended_data_orig.append(dm[Orig])
    else:
        Orig = dm['PassengerState'].diff() == 1
        appended_data_orig.append(dm[Orig])
#########################################################

    appended_data_dest = []
    dm = list(dt)[1]
    Dest = dm['PassengerState'].shift(-1).diff() == -1
    appended_data_dest.append(dm[Dest])
######################################################### 
    All_Orig = pd.concat(appended_data_orig,axis=0)    
    All_Dest = pd.concat(appended_data_dest,axis=0)    
    
#########################################################
    if len(All_Orig) > len(All_Dest):
        number = len(All_Dest)
    else:
        number = len(All_Orig)

#########################################################
    dk = pd.DataFrame(np.random.randn(int(number),4),
                      columns=['GPSLongitude_O','GPSLatitude_O','GPSLongitude_D','GPSLatitude_D'])

    All_Orig.reset_index(inplace=True)
    All_Dest.reset_index(inplace=True)

    for i in range(0,int(number)):
        dk['GPSLongitude_O'][i] = All_Orig['GPSLongitude'][i]
        dk['GPSLatitude_O'][i] = All_Orig['GPSLatitude'][i]
        dk['GPSLongitude_D'][i] = All_Dest['GPSLongitude'][i]
        dk['GPSLatitude_D'][i] = All_Dest['GPSLatitude'][i]
    return dk

# %%
for dt in gp:
    appended_data = get_data(dt)
    appended_data.to_sql('OD_DATA',engine,if_exists='append')

# %%
for dt in gp:
    appended_data = get_data(dt)
    appended_data.to_csv(r'D:\Vgis_data\Multi-Source-Data\show\OD_DATA2.csv',mode='a',header=False,index=False)
